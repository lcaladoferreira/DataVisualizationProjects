# %% [markdown]
# <a href="https://colab.research.google.com/github/lcaladoferreira/DataVisualizationProjects/blob/main/Embraer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Carregar o dataset
file_path = '/content/drive/MyDrive/Aviação Comercial 2024/embraer_detalhado_peso.csv'
df = pd.read_csv(file_path)

# Renomear colunas
df.rename(columns={
    'ano_de_fabricacao': 'ano_fabricacao',
    'categoria_de_registro': 'categoria_registro',
    'situacao_de_aeronavegabilidade': 'situacao_aeronavegabilidade',
    'peso_maximo_de_decolagem': 'peso_max_decolagem'
}, inplace=True)

# Verificar valores ausentes
missing_values = df.isnull().sum()

# Converter tipos de dados
df['ano_fabricacao'] = df['ano_fabricacao'].astype('Int64')  # Permitir valores ausentes
df['peso_max_decolagem'] = df['peso_max_decolagem'].str.replace(' - Kg', '').astype(float)

# Remover duplicatas
df.drop_duplicates(inplace=True)

# Exibir informações do dataframe após a limpeza
df.info(), missing_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2112 entries, 0 to 2235
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   prefixo                         2112 non-null   object
#  1   url                             2112 non-null   object
#  2   ano_fabricacao                  1708 non-null   Int64
#  3   proprietario                    2111 non-null   object
#  4   cpf_cnpj                        2088 non-null   object
#  5   operador                        2109 non-null   object
#  6   cpf_cnpj.1                      2088 non-null   object
#  7   categoria_registro              2106 non-null   object
#  8   modelo                          2111 non-null   object
#  9   numero_de_serie                 2112 non-null   object
#  10  peso_max_decolagem              2109 non-null   float64
#  11  situação_de_aeronavegabilidade  2109 non-null   object
# ...

# %%
df.rename(columns={
    'ano_de_fabricacao': 'ano_fabricacao',
    'categoria_de_registro': 'categoria_registro',
    'situacao_de_aeronavegabilidade': 'situacao_aeronavegabilidade',  # Verificar a ortografia correta
    'peso_maximo_de_decolagem': 'peso_max_decolagem'
}, inplace=True)

# %%
# Verificar o tipo de dado da coluna
print(df['peso_max_decolagem'].dtype)

# Converter para string se necessário
if not pd.api.types.is_string_dtype(df['peso_max_decolagem']):
    df['peso_max_decolagem'] = df['peso_max_decolagem'].astype(str)

# Substituir ' - Kg' e converter para float
df['peso_max_decolagem'] = df['peso_max_decolagem'].str.replace(' - Kg', '').astype(float)
# Out:
# float64

# %%
# Renomear colunas com nomes verificados
df.rename(columns={
    'ano_de_fabricacao': 'ano_fabricacao',
    'categoria_de_registro': 'categoria_registro',
    'situacao_de_aeronavegabilidade': 'situacao_aeronavegabilidade',  # Verificar nome correto
    'peso_maximo_de_decolagem': 'peso_max_decolagem'
}, inplace=True)

# Verificar valores ausentes
missing_values = df.isnull().sum()

# Verificar e Converter tipo de dado da coluna 'peso_max_decolagem'
if not pd.api.types.is_string_dtype(df['peso_max_decolagem']):
    df['peso_max_decolagem'] = df['peso_max_decolagem'].astype(str)

# Substituir ' - Kg' e converter para float
df['peso_max_decolagem'] = df['peso_max_decolagem'].str.replace(' - Kg', '').astype(float)

# Converter tipos de dados
df['ano_fabricacao'] = df['ano_fabricacao'].astype('Int64')  # Permitir valores ausentes

# Remover duplicatas
df.drop_duplicates(inplace=True)

# Exibir informações do dataframe após a limpeza
print(df.info())
print(missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2112 entries, 0 to 2235
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   prefixo                         2112 non-null   object
#  1   url                             2112 non-null   object
#  2   ano_fabricacao                  1708 non-null   Int64
#  3   proprietario                    2111 non-null   object
#  4   cpf_cnpj                        2088 non-null   object
#  5   operador                        2109 non-null   object
#  6   cpf_cnpj.1                      2088 non-null   object
#  7   categoria_registro              2106 non-null   object
#  8   modelo                          2111 non-null   object
#  9   numero_de_serie                 2112 non-null   object
#  10  peso_max_decolagem              2109 non-null   float64
#  11  situação_de_aeronavegabilidade  2109 non-null   object
# ...

# %%
# Renomear colunas
df.rename(columns={
    'ano_de_fabricacao': 'ano_fabricacao',
    'categoria_de_registro': 'categoria_registro',
    'situacao_de_aeronavegabilidade': 'situacao_aeronavegabilidade',  # Verificar nome correto
    'peso_maximo_de_decolagem': 'peso_max_decolagem'
}, inplace=True)

# Limpeza e Pré-processamento
if not pd.api.types.is_string_dtype(df['peso_max_decolagem']):
    df['peso_max_decolagem'] = df['peso_max_decolagem'].astype(str)
df['peso_max_decolagem'] = df['peso_max_decolagem'].str.replace(' - Kg', '').astype(float)
df['ano_fabricacao'] = df['ano_fabricacao'].astype('Int64')
df.drop_duplicates(inplace=True)

# Exibir informações do dataframe após a limpeza
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2112 entries, 0 to 2235
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   prefixo                         2112 non-null   object
#  1   url                             2112 non-null   object
#  2   ano_fabricacao                  1708 non-null   Int64
#  3   proprietario                    2111 non-null   object
#  4   cpf_cnpj                        2088 non-null   object
#  5   operador                        2109 non-null   object
#  6   cpf_cnpj.1                      2088 non-null   object
#  7   categoria_registro              2106 non-null   object
#  8   modelo                          2111 non-null   object
#  9   numero_de_serie                 2112 non-null   object
#  10  peso_max_decolagem              2109 non-null   float64
#  11  situação_de_aeronavegabilidade  2109 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calcular a frequência dos proprietários de aeronaves
freq_proprietario = df['proprietario'].value_counts()

# Limitar o número de proprietários a serem exibidos para melhor visualização
top_n = 20  # Defina o número de proprietários mais frequentes a serem mostrados

plt.figure(figsize=(10, 8))
sns.barplot(y=freq_proprietario.head(top_n).index, x=freq_proprietario.head(top_n).values, palette='viridis')
plt.title(f'Top {top_n} Proprietários de Aeronaves por Frequência')
plt.xlabel('Número de Aeronaves')
plt.ylabel('Proprietário')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-cde3e573bf37>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=freq_proprietario.head(top_n).index, x=freq_proprietario.head(top_n).values, palette='viridis')

# %%
# Calcular a frequência dos proprietários de aeronaves
freq_proprietario = df['operador'].value_counts()

# Limitar o número de proprietários a serem exibidos para melhor visualização
top_n = 20  # Defina o número de proprietários mais frequentes a serem mostrados

plt.figure(figsize=(10, 8))
sns.barplot(y=freq_proprietario.head(top_n).index, x=freq_proprietario.head(top_n).values, palette='viridis')
plt.title(f'Top {top_n} Operadores da Marca Embraer')
plt.xlabel('Número de Aeronaves')
plt.ylabel('operador')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-904d5bfab09f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=freq_proprietario.head(top_n).index, x=freq_proprietario.head(top_n).values, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Análise de distribuição de frequências
freq_ano_fabricacao = df['ano_fabricacao'].value_counts().sort_index()
freq_modelo = df['modelo'].value_counts()
freq_categoria_registro = df['categoria_registro'].value_counts()
freq_situacao_aeronavegabilidade = df['situação_de_aeronavegabilidade'].value_counts()

# Medidas descritivas
desc_ano_fabricacao = df['ano_fabricacao'].describe()
desc_peso_max_decolagem = df['peso_max_decolagem'].describe()

# Visualizações
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(df['ano_fabricacao'].dropna(), kde=True)
plt.title('Distribuição do Ano de Fabricação')
plt.xlim(1950, 2025)

plt.subplot(2, 2, 2)
sns.countplot(y=df['modelo'], order=freq_modelo.index)
plt.title('Distribuição dos Modelos de Aeronaves')

plt.subplot(2, 2, 3)
sns.countplot(y=df['categoria_registro'], order=freq_categoria_registro.index)
plt.title('Distribuição das Categorias de Registro')

plt.subplot(2, 2, 4)
sns.countplot(y=df['situação_de_aeronavegabilidade'], order=freq_situacao_aeronavegabilidade.index)
plt.title('Distribuição da Situação de Aeronavegabilidade')

# Calcular a frequência dos modelos de aeronaves
freq_modelo = df['modelo'].value_counts()

# Limitar o número de modelos a serem exibidos para melhor visualização
top_n = 20  # Defina o número de modelos mais frequentes a serem mostrados

plt.figure(figsize=(10, 8))
sns.barplot(y=freq_modelo.head(top_n).index, x=freq_modelo.head(top_n).values, palette='viridis')
plt.title(f'Top {top_n} Modelos de Aeronaves por Frequência')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Modelo de Aeronave')
plt.tight_layout()
plt.show()


desc_ano_fabricacao, desc_peso_max_decolagem
# Out:
# <ipython-input-9-1c6d02dc507a>:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=freq_modelo.head(top_n).index, x=freq_modelo.head(top_n).values, palette='viridis')
# (count         1708.0
#  mean     1999.282787
#  std        17.098262
#  min           1971.0
#  25%           1980.0
#  50%           2008.0
#  75%           2013.0
#  max           2024.0
#  Name: ano_fabricacao, dtype: Float64,
#  count     2109.000000
#  mean      6937.968706
#  std      12206.116711
#  min          0.000000
#  25%       1900.000000
#  50%       2073.000000
#  75%       5600.000000
#  max      61500.000000
#  Name: peso_max_decolagem, dtype: float64)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Análise de distribuição de frequências
freq_ano_fabricacao = df['ano_fabricacao'].value_counts().sort_index()
freq_modelo = df['modelo'].value_counts()
freq_categoria_registro = df['categoria_registro'].value_counts()
freq_situacao_aeronavegabilidade = df['situação_de_aeronavegabilidade'].value_counts()

# Medidas descritivas
desc_ano_fabricacao = df['ano_fabricacao'].describe()
desc_peso_max_decolagem = df['peso_max_decolagem'].describe()

# Visualizações
plt.figure(figsize=(15, 10))

# Distribuição do Ano de Fabricação
plt.subplot(2, 2, 1)
sns.histplot(df['ano_fabricacao'].dropna(), kde=True)
plt.title('Distribuição do Ano de Fabricação')
plt.xlabel('Ano de Fabricação')
plt.ylabel('Contagem')

# Ajustar os limites do eixo X para refletir a faixa de 1950 a 2025
plt.xlim(1950, 2025)

plt.subplot(2, 2, 2)
sns.countplot(y=df['modelo'], order=freq_modelo.index)
plt.title('Distribuição dos Modelos de Aeronaves')

plt.subplot(2, 2, 3)
sns.countplot(y=df['categoria_registro'], order=freq_categoria_registro.index)
plt.title('Distribuição das Categorias de Registro')

plt.subplot(2, 2, 4)
sns.countplot(y=df['situação_de_aeronavegabilidade'], order=freq_situacao_aeronavegabilidade.index)
plt.title('Distribuição da Situação de Aeronavegabilidade')

plt.tight_layout()
plt.show()

desc_ano_fabricacao, desc_peso_max_decolagem
# Out:
# (count         1708.0
#  mean     1999.282787
#  std        17.098262
#  min           1971.0
#  25%           1980.0
#  50%           2008.0
#  75%           2013.0
#  max           2024.0
#  Name: ano_fabricacao, dtype: Float64,
#  count     2109.000000
#  mean      6937.968706
#  std      12206.116711
#  min          0.000000
#  25%       1900.000000
#  50%       2073.000000
#  75%       5600.000000
#  max      61500.000000
#  Name: peso_max_decolagem, dtype: float64)
